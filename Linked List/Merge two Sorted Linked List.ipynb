# %%
# TC: O(n + m)   → we traverse both lists once
# SC: O(n + m)   → recursion stack (worst case)


def mergeTwoLists(list1,list2):
    
    # Base cases
    if list1 is None:
        return list2
    if list2 is None:
        return list1
    
    # Choose smaller node
    if list1.val <= list2.val:
        temp = list1   # take node (not value)
        
        # Recursively merge remaining
        temp.next = self.mergeTwoLists(list1.next, list2)
    
    else:
        temp = list2
        
        temp.next = self.mergeTwoLists(list1, list2.next)
    
    return temp
