# %%
def maxProfit(arr):
    minPrice=float('inf')
    maxProfit=0

    for i in range(len(arr)):
        if arr[i]<minPrice
# Out:
# 1

# %%
def singleNum(arr):
    # Time Complexity: O(n)
    # Space Complexity: O(1)

    result = 0
    for num in arr:
        result ^= num
    return result

arr = [2,2,1]
print(singleNum(arr))
# Out:
# 1
