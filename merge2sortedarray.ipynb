# %%
def merge2sortedarray(arr1,arr2):
    i=m-1
    j=n-1
    k=m+n-1

    while i>0 and j>0:
        if arr[i] < arr[j]:
            arr[k]=arr[i]
            i-=1
        else:
            arr[k]=arr[j]
# Out:
# Result: [2, 4]
