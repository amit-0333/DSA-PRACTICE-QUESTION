# %%
from collections import deque

# Tree Node
class Node:

    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None


class Solution:

    # TC: O(N log N)
    # BFS traversal O(N) + sorting keys O(N log N)

    # SC: O(N)
    # Queue + hashmap

    def topView(self, root):

        if root is None:
            return []

        mp = {}   # horizontal distance -> node value
        q = deque()

        # (node, horizontal distance)
        q.append((root, 0))

        while q:
            node, hd = q.popleft()

            # store only first node at each hd
            if hd not in mp:
              mp[hd] = node.val

            if node.left:
                q.append((node.left, hd - 1))
            if node.right:
                q.append((node.right, hd + 1))

        # return sorted order of horizontal distance
        return [mp[i] for i in sorted(mp)]


# ---------------- DRIVER CODE ----------------

# Build sample tree
#         20
#       /    \
#      8      22
#     / \       \
#    5   3       25
#       / \
#      10 14

root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(5)
root.left.right = Node(3)
root.right.right = Node(25)
root.left.right.left = Node(10)
root.left.right.right = Node(14)

# Call function
obj = Solution()
print(obj.topView(root))
# Out:
# [5, 8, 20, 22, 25]
