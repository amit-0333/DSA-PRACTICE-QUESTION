# %%
def findMissingAndRepeatedValues(grid):
    n=len(grid)
    repeated=-1
    seen=set()
    missing=-1

    for num in grid:
        for num in row:
            if num in seen:
                repeated=num
            else:
                seen.add(num)
    for i in range(1,n*n+1):
        if i not in seen:
            missing=i
            break
    return missing,repeated

grid = [[1,3],[2,2]]
print(findMissingAndRepeatedValues(grid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 20
#      17     return missing,repeated
#      19 grid = [[1,3],[2,2]]
# ---> 20 print(findMissingAndRepeatedValues(grid))
#
# Cell In[6], line 8, in findMissingAndRepeatedValues(grid)
#       5 missing=-1
#       7 for num in grid:
# ----> 8     for num in row:
#       9         if num in seen:
#      10             repeated=num
#
# NameError: name 'row' is not defined
